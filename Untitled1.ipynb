# %%
ls
# Out:
# answer.txt  aws/  ChatBot/  cv.pdf  jupyter /  Untitled1.ipynb  Untitled.ipynb

# %%
import csv
import glob
import os
import re
import sys                        
import subprocess
import os
import uuid
import pandas as pd
from builtins import str

from tika import parser
pdfile= parser.from_file("cv.pdf")
output=subprocess.check_output(["less","cv.pdf"])

dataextracted=pdfile["content"].encode('utf-8')

l1=dataextracted.splitlines()

# %%
l1
# Out:
# [b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'',
#  b'Sunil Sharma \xe2\x80\x93 Curriculum Vitae',
#  b'',
#  b'',
#  b'Sunil Sharma',
#  b'Curriculum Vitae',
#  b'',
#  b'H.No 320,Ajit Nagar',
#  b'Kapurthala,Punjab,144601',
#  b'',
#  b'H (+91) 7986359035',
#  b'B sharma.sunil5@tcs.com',
#  b'',
#  b'Education',
#  b'Qualification Master of Technology - Digital Communication',
#  b'',
#  b'Institute Indian Institute of Information Technology and Management, Gwalior',
#  b'Duration July 2016 - May 2018',
#  b'',
#  b'Overall CGPA 7.42',
#  b'',
#  b'Qualification Bachelor of Technology - Electronics and Communication Engineering',
#  b'Institute Lovely Professional University, Phagwara, Punjab',
#  b'Duration July 2012 - June 2016',
#  b'',
#  b'Overall CGPA 9.27',
#  b'',
#  b'Work Experience',
#  b'Title Jarvis Bot',
#  b'',
#  b'Description A conversational banking assistant AI bot that helps user to view their account balance and let them',
#  b'change their basic details. The bot uses NLP and Machine Learning for the conversational flow,',
#  b'Query optimization. The front-end was made using NodeJS and the back-end is created using Google',
#  b'dialog flow . The bot works on the principals of natural language understanding to do the intent',
#  b'classification of the question and gives suitable response according to trained corpus.',
#  b'',
#  b'Title Damage Reporting System',
#  b'Description A portal is created for reporting of property damage, which enable user to upload picture of damaged',
#  b'',
#  b'property using a chatbot.In the backend a trained Convolution neural network model is used for',
#  b'classification of the damaged property and its severity. The transfer learning is done using pre-built',
#  b'inception V3 model for object recognition. second model was trained using 2000 images of different',
#  b'property damage and severity. Keras and Tensorflow libraries are used for CNN model and API',
#  b'creation.',
#  b'',
#  b'Title Health bot',
#  b'Description A medical assistant chatbot to connect patient to its doctor. Helps patient by giving recommendation',
#  b'',
#  b'based upon symptoms of illness. The health bot was train and tested using RASA library, which is an',
#  b'open source conversational AI platform for chatbot creation. In the backend the LSTM algorithm is',
#  b'used for training of the model.The model can be trained on a personalized corpus to give user a sense',
#  b'of exclusivity. The corpus can be feed in from a user interface using flask API.',
#  b'',
#  b'Title Automated Document verification system',
#  b'Description A system capable of verifying and extracting the imperative information from a document related to',
#  b'',
#  b'banking and financial services. The classification of the document was done using Convolution neural',
#  b'network. Feature and information extraction is done using OpenCV and Pytesseract libraries, which',
#  b'are well known computer vision tools. This system is integrated with Elastic search engine for better',
#  b'information retrieval.',
#  b'',
#  b'1/3',
#  b'',
#  b'mailto:sharma.sunil5@tcs.com',
#  b'',
#  b'',
#  b'Research Experience',
#  b'Place Indian Institute of Information Technology and Management. Gwalior',
#  b'',
#  b'Duration August 2017 - April 2018',
#  b'Project A Deep Convolution Neural Network based approach for Diabetic Retinopathy detection and classification',
#  b'',
#  b'Supervisor Prof. Anupam Shukla',
#  b'Research',
#  b'Objective',
#  b'',
#  b'To construct and analysis of a Deep Convolution Neural Network to detect and grade diabetic retinopathy',
#  b'images.',
#  b'',
#  b'Individual',
#  b'Responsibility',
#  b'',
#  b'Pre-processed 50,000 images of diabetic retinopathy taken from Kaggle Competition and Messidor',
#  b'experiment. Cropping, size normalization, image augmentation and Implemented Deep CNN architecture',
#  b'using python.',
#  b'',
#  b'Outcomes The proposed Deep CNN algorithm produced significant results with 93% area under the curve (AUC)',
#  b'for the kaggle dataset and 91% AUC for the messidor dataset. The sensitivity and specificity for the',
#  b'kaggle dataset were 90.22% and 85.13%. The corresponding values for messidor dataset were 91.07',
#  b'and 80.23%. The results outperformed many existing studies.',
#  b'',
#  b'Tools used Python 3.5, Numpy, Matplotlib, Scikit-learn, Keras',
#  b'',
#  b'Research Interest',
#  b'Machine Learning, Statistics, Artificial Intelligence, Neural Networks, Natural Language Processing,',
#  b'Deep Learning.',
#  b'',
#  b'Publication',
#  b'An intelligible deep convolution neural network based approach for classification of diabetic retinopathy.DE',
#  b'GRUYTER: Bio-Algorithms and Med-Systems. Published Online: 2018-06-22.',
#  b'DOI:https://doi.org/10.1515/bams-2018-0011',
#  b'',
#  b'Projects',
#  b'Title Intent Classification using a Deep Learning Bag-of-Words Model for Predicting Movie Review Sentiment',
#  b'',
#  b'Description A multilayer Perceptron bag-of-words model is build on a movie review corpus. The model is built for',
#  b'sentiment analysis purpose to distinguish between a positive and negative reviews. A basic sequential',
#  b'model is created using Keras, after preprocessing of the movie review corpus.',
#  b'',
#  b'Project link Github repo',
#  b'',
#  b'Title An Ensemble model for Diabetic retninopathy detection',
#  b'Description A model is trained and tested using ensemble learning approach. Different Machine learning classifiers',
#  b'',
#  b'are used such as SVM, MLP, KNN, Random Forest, Decision tree, Adaboost for classification purpose.',
#  b'Ensemble model works upon majority voting criteria. all different classifiers trained with same training',
#  b'data and then tested using uniform and weighted voting Ensemble model.',
#  b'',
#  b'Project link Github repo',
#  b'',
#  b'Major Competencies',
#  b'E2 Digital : Deep Learning',
#  b'E2 Digital : Artificial Intelligence(AI)',
#  b'E2 Digital : Machine Learning',
#  b'E1 Digital : Data Science',
#  b'',
#  b'Specialization',
#  b'Deep Learning, a 5-course specialization by deeplearning.ai on Coursera. Specialization Certificate',
#  b'earned on September 29, 2018. Certificate link',
#  b'',
#  b'2/3',
#  b'',
#  b'https://doi.org/10.1515/bams-2018-0011',
#  b'https://github.com/Iamsunilsharma/Deep-Learning-Based-Intent-Classification-using-Bag-of-Word-representation',
#  b'https://github.com/Iamsunilsharma/Ensemble-model-for-machine-learning-classification-problem-',
#  b'https://www.coursera.org/account/accomplishments/specialization/2Q2QABZPL3PB',
#  b'',
#  b'',
#  b'Applied Data Science with Python, a 5-course specialization by University of Michigan on Coursera.',
#  b'Specialization Certificate earned on October 4, 2018. Certificate link',
#  b'',
#  b'Certification',
#  b'* Machine Learning by Stanford University on Coursera. Certificate link',
#  b'* Elements Of AI by University of Helsinki,Finland Certificate link',
#  b'* Natural Language Processing by National Research University Higher School of Economics on Coursera.',
#  b'',
#  b'Certificate link',
#  b'* Machine Learning: Regression by University of Washington on Coursera. Certificate link',
#  b'* Machine Learning: Classification by University of Washington on Coursera. Certificate link',
#  b'* Advanced RPA Professional Certification, License AAADVC-34652219',
#  b'',
#  b'Programming Languages',
#  b'Langauge Python, C++, C',
#  b'Markup LATEX, HTML,CSS',
#  b'',
#  b'VersionControl GIT',
#  b'WebFramework Flask,Django',
#  b'',
#  b'OS Linux,Windows',
#  b'',
#  b'Achievements and Award',
#  b'* University Topper in B.Tech ECE (Honours) with CGPA 9.27, Awarded with Academic Honor Certificate.',
#  b'* I have taken the i-class of different ILP associates in a live session on the topic of Machine Learning,',
#  b'',
#  b'The participant ILP were from Hyderabad, Chennai, Trivandrum, Guwahati and Gandhinagar.',
#  b'* Cleared GATE 2016 with 97.45 percentile.',
#  b'* National cadet corps for \xe2\x80\x99A\xe2\x80\x99 certificate.',
#  b'* Stood Second Place in Inter- IIIT Sports meet in basketball.',
#  b'* First Position in Regional level Basketball championship under K.V.S Chandigarh region-2010',
#  b'',
#  b'Interest',
#  b'Competitive',
#  b'',
#  b'Programming',
#  b'I am very much interested in solving problems. I use git for my projects and all the projects mentioned',
#  b'are on the Github as a public repo. Excluding some, they are ongoing projects and are as a private',
#  b'repository of github.',
#  b'',
#  b'Teaching I am a strong believer that the best way to learn is to teach, I love to teach',
#  b'',
#  b'Proudly made in LATEX',
#  b'3/3',
#  b'',
#  b'https://www.coursera.org/account/accomplishments/specialization/KB76YD3L3RBQ',
#  b'https://www.coursera.org/account/accomplishments/certificate/VP27DTZWY8KY',
#  b'https://certificates.mooc.fi/validate/8whps8xeplq',
#  b'https://www.coursera.org/account/accomplishments/certificate/AR46YAYKCG6Q',
#  b'https://www.coursera.org/account/accomplishments/certificate/SDRAM3J6J95B',
#  b'https://www.coursera.org/account/accomplishments/certificate/59TR5A4AJN8X',
#  b'https://github.com/Iamsunilsharma',
#  b'',
#  b'\tEducation',
#  b'\tWork Experience',
#  b'\tResearch Experience',
#  b'\tResearch Interest',
#  b'\tPublication',
#  b'\tProjects',
#  b'\tMajor Competencies',
#  b'\tSpecialization',
#  b'\tCertification',
#  b'\tProgramming Languages',
#  b'\tAchievements and Award',
#  b'\tInterest',
#  b'']

# %%
import PyPDF2
pdfFileObject = open('cv.pdf', 'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObject)
count = pdfReader.numPages
for i in range(count):
    page = pdfReader.getPage(i)
    print(page.extractText())
# Out:
# SunilSharma
# CurriculumVitae
# H.No320,AjitNagar
# Kapurthala,Punjab,144601
# H
# (+91)7986359035
# B
# sharma.sunil5@tcs.com
# Education
# Quali˝cation
# MasterofTechnology-DigitalCommunication
# Institute
# IndianInstituteofInformationTechnologyandManagement,Gwalior
# Duration
# July2016-May2018
# OverallCGPA
# 7.42
# Quali˝cation
# BachelorofTechnology-ElectronicsandCommunicationEngineering
# Institute
# LovelyProfessionalUniversity,Phagwara,Punjab
# Duration
# July2012-June2016
# OverallCGPA
# 9.27
# WorkExperience
# Title
# JarvisBot
# Description
# AconversationalbankingassistantAIbotthathelpsusertoviewtheiraccountbalanceandletthem
# changetheirbasicdetails.Thebotuses
# NLP
# and
# MachineLearning
# fortheconversational˛ow,
# Queryoptimization.Thefront-endwasmadeusingNodeJSandtheback-endiscreatedusing
# Google
# dialog˛ow
# .Thebotworksontheprincipalsofnaturallanguageunderstandingtodotheintent
# classi˝cationofthequestionandgivessuitableresponseaccordingtotrainedcorpus.
# Title
# DamageReportingSystem
# Description
# Aportaliscreatedforreportingofpropertydamage,whichenableusertouploadpictureofdamaged
# propertyusingachatbot.Inthebackendatrained
# Convolutionneuralnetwork
# modelisusedfor
# classi˝cationofthedamagedpropertyanditsseverity.Thetransferlearningisdoneusingpre-built
# inceptionV3modelforobjectrecognition.secondmodelwastrainedusing2000imagesofdi˙erent
# propertydamageandseverity.
# Keras
# and
# Tensor˛ow
# librariesareusedforCNNmodelandAPI
# creation.
# Title
# Healthbot
# Description
# Amedicalassistantchatbottoconnectpatienttoitsdoctor.Helpspatientbygivingrecommendation
# baseduponsymptomsofillness.Thehealthbotwastrainandtestedusing
# RASA
# library,whichisan
# opensourceconversationalAIplatformforchatbotcreation.Inthebackendthe
# LSTM
# algorithmis
# usedfortrainingofthemodel.Themodelcanbetrainedonapersonalizedcorpustogiveuserasense
# ofexclusivity.Thecorpuscanbefeedinfromauserinterfaceusing
# ˛askAPI
# .
# Title
# AutomatedDocumentveri˝cationsystem
# Description
# Asystemcapableofverifyingandextractingtheimperativeinformationfromadocumentrelatedto
# bankingand˝nancialservices.Theclassi˝cationofthedocumentwasdoneusing
# Convolutionneural
# network
# .Featureandinformationextractionisdoneusing
# OpenCV
# and
# Pytesseract
# libraries,which
# arewellknowncomputervisiontools.Thissystemisintegratedwith
# Elasticsearchengine
# forbetter
# informationretrieval.
# 1/3
#
# ResearchExperience
# Place
# IndianInstituteofInformationTechnologyandManagement.Gwalior
# Duration
# August2017-April2018
# Project
# ADeepConvolutionNeuralNetworkbasedapproachforDiabeticRetinopathydetectionandclassi˝cation
# Supervisor
# Prof.AnupamShukla
# Research
# Objective
# ToconstructandanalysisofaDeepConvolutionNeuralNetworktodetectandgradediabeticretinopathy
# images.
# Individual
# Responsibility
# Pre-processed50,000imagesofdiabeticretinopathytakenfromKaggleCompetitionandMessidor
# experiment.Cropping,sizenormalization,imageaugmentationandImplementedDeepCNNarchitecture
# usingpython.
# Outcomes
# TheproposedDeepCNNalgorithmproducedsigni˝cantresultswith93%areaunderthecurve(AUC)
# forthekaggledatasetand91%AUCforthemessidordataset.Thesensitivityandspeci˝cityforthe
# kaggledatasetwere90.22%and85.13%.Thecorrespondingvaluesformessidordatasetwere91.07
# and80.23%.Theresultsoutperformedmanyexistingstudies.
# Toolsused
# Python3.5,Numpy,Matplotlib,Scikit-learn,Keras
# ResearchInterest
# MachineLearning,Statistics,Arti˝cialIntelligence,NeuralNetworks,NaturalLanguageProcessing,
# DeepLearning.
# Publication
# Anintelligibledeepconvolutionneuralnetworkbasedapproachforclassi˝cationofdiabeticretinopathy.DE
# GRUYTER:Bio-AlgorithmsandMed-Systems.PublishedOnline:2018-06-22.
# DOI:
# https://doi.org/10.1515/bams-2018-0011
# Projects
# Title
# IntentClassi˝cationusingaDeepLearningBag-of-WordsModelforPredictingMovieReviewSentiment
# Description
# AmultilayerPerceptronbag-of-wordsmodelisbuildonamoviereviewcorpus.Themodelisbuiltfor
# sentimentanalysispurposetodistinguishbetweenapositiveandnegativereviews.Abasicsequential
# modeliscreatedusingKeras,afterpreprocessingofthemoviereviewcorpus.
# Projectlink
# Githubrepo
# Title
# AnEnsemblemodelforDiabeticretninopathydetection
# Description
# Amodelistrainedandtestedusingensemblelearningapproach.Di˙erentMachinelearningclassi˝ers
# areusedsuchasSVM,MLP,KNN,RandomForest,Decisiontree,Adaboostforclassi˝cationpurpose.
# Ensemblemodelworksuponmajorityvotingcriteria.alldi˙erentclassi˝erstrainedwithsametraining
# dataandthentestedusinguniformandweightedvotingEnsemblemodel.
# Projectlink
# Githubrepo
# MajorCompetencies
# E2
# Digital:DeepLearning
# E2
# Digital:Arti˝cialIntelligence(AI)
# E2
# Digital:MachineLearning
# E1
# Digital:DataScience
# Specialization
# DeepLearning,a5-coursespecializationbydeeplearning.aionCoursera.SpecializationCerti˝cate
# earnedonSeptember29,2018.
# Certi˝catelink
# 2/3
#
# AppliedDataSciencewithPython,a5-coursespecializationbyUniversityofMichiganonCoursera.
# SpecializationCerti˝cateearnedonOctober4,2018.
# Certi˝catelink
# Certi˝cation
# *
# MachineLearningbyStanfordUniversityonCoursera.
# Certi˝catelink
# *
# ElementsOfAIbyUniversityofHelsinki,Finland
# Certi˝catelink
# *
# NaturalLanguageProcessingbyNationalResearchUniversityHigherSchoolofEconomicsonCoursera.
# Certi˝catelink
# *
# MachineLearning:RegressionbyUniversityofWashingtononCoursera.
# Certi˝catelink
# *
# MachineLearning:Classi˝cationbyUniversityofWashingtononCoursera.
# Certi˝catelink
# *
# AdvancedRPAProfessionalCerti˝cation,LicenseAAADVC-34652219
# ProgrammingLanguages
# Langauge
# Python,C++,C
# Markup
# L
# A
# T
# E
# X,HTML,CSS
# VersionControl
# GIT
# WebFramework
# Flask,Django
# OS
# Linux,Windows
# AchievementsandAward
# *
# UniversityTopperinB.TechECE(Honours)withCGPA9.27,AwardedwithAcademicHonorCerti˝cate.
# *
# Ihavetakenthei-classofdi˙erentILPassociatesinalivesessiononthetopicofMachineLearning,
# TheparticipantILPwerefromHyderabad,Chennai,Trivandrum,GuwahatiandGandhinagar.
# *
# ClearedGATE2016with97.45percentile.
# *
# Nationalcadetcorpsfor'A'certi˝cate.
# *
# StoodSecondPlaceinInter-IIITSportsmeetinbasketball.
# *
# FirstPositioninRegionallevelBasketballchampionshipunderK.V.SChandigarhregion-2010
# Interest
# Competitive
# Programming
# Iamverymuchinterestedinsolvingproblems.Iusegitformyprojectsandalltheprojectsmentioned
# areonthe
# Github
# asapublicrepo.Excludingsome,theyareongoingprojectsandareasaprivate
# repositoryofgithub.
# Teaching
# Iamastrongbelieverthatthebestwaytolearnistoteach,Ilovetoteach
# ProudlymadeinL
# A
# T
# E
# X
# 3/3

# %%
import sys
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import XMLConverter, HTMLConverter, TextConverter
from pdfminer.layout import LAParams
import io

def pdfparser(data):

    fp = open(data, 'rb')
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    # Create a PDF interpreter object.
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    # Process each page contained in the document.

    for page in PDFPage.get_pages(fp):
        interpreter.process_page(page)
        data =  retstr.getvalue()

    print(data)

if __name__ == '__main__':
    pdfparser('cv.pdf')
# Out:
# Sunil Sharma
# Curriculum Vitae
#
# H.No 320,Ajit Nagar
# Kapurthala,Punjab,144601
# (cid:72) (+91) 7986359035
# (cid:66) sharma.sunil5@tcs.com
#
# Education
#
# Qualiﬁcation Master of Technology - Digital Communication
#
# Institute Indian Institute of Information Technology and Management, Gwalior
# Duration July 2016 - May 2018
#
# Overall CGPA 7.42
#
# Qualiﬁcation Bachelor of Technology - Electronics and Communication Engineering
#
# Institute Lovely Professional University, Phagwara, Punjab
# Duration July 2012 - June 2016
#
# Overall CGPA 9.27
#
# Work Experience
#
# Title Jarvis Bot
#
# Description A conversational banking assistant AI bot that helps user to view their account balance and let them
# change their basic details. The bot uses NLP and Machine Learning for the conversational ﬂow,
# Query optimization. The front-end was made using NodeJS and the back-end is created using Google
# dialog ﬂow. The bot works on the principals of natural language understanding to do the intent
# classiﬁcation of the question and gives suitable response according to trained corpus.
#
# Title Damage Reporting System
#
# Description A portal is created for reporting of property damage, which enable user to upload picture of damaged
# property using a chatbot.In the backend a trained Convolution neural network model is used for
# classiﬁcation of the damaged property and its severity. The transfer learning is done using pre-built
# inception V3 model for object recognition. second model was trained using 2000 images of diﬀerent
# property damage and severity. Keras and Tensorﬂow libraries are used for CNN model and API
# creation.
#
# Title Health bot
#
# Description A medical assistant chatbot to connect patient to its doctor. Helps patient by giving recommendation
# based upon symptoms of illness. The health bot was train and tested using RASA library, which is an
# open source conversational AI platform for chatbot creation. In the backend the LSTM algorithm is
# used for training of the model.The model can be trained on a personalized corpus to give user a sense
# of exclusivity. The corpus can be feed in from a user interface using ﬂask API.
#
# Title Automated Document veriﬁcation system
#
# Description A system capable of verifying and extracting the imperative information from a document related to
# banking and ﬁnancial services. The classiﬁcation of the document was done using Convolution neural
# network. Feature and information extraction is done using OpenCV and Pytesseract libraries, which
# are well known computer vision tools. This system is integrated with Elastic search engine for better
# information retrieval.
#
# 1/3
#
# Research Experience
#
# Place Indian Institute of Information Technology and Management. Gwalior
#
# Duration August 2017 - April 2018
# Project A Deep Convolution Neural Network based approach for Diabetic Retinopathy detection and classiﬁcation
#
# Supervisor Prof. Anupam Shukla
# Research
# Objective
# Individual
# Responsibility
#
# To construct and analysis of a Deep Convolution Neural Network to detect and grade diabetic retinopathy
# images.
# Pre-processed 50,000 images of diabetic retinopathy taken from Kaggle Competition and Messidor
# experiment. Cropping, size normalization, image augmentation and Implemented Deep CNN architecture
# using python.
#
# Outcomes The proposed Deep CNN algorithm produced signiﬁcant results with 93% area under the curve (AUC)
# for the kaggle dataset and 91% AUC for the messidor dataset. The sensitivity and speciﬁcity for the
# kaggle dataset were 90.22% and 85.13%. The corresponding values for messidor dataset were 91.07
# and 80.23%. The results outperformed many existing studies.
#
# Tools used Python 3.5, Numpy, Matplotlib, Scikit-learn, Keras
#
# Research Interest
# Machine Learning, Statistics, Artiﬁcial Intelligence, Neural Networks, Natural Language Processing,
# Deep Learning.
# Publication
# An intelligible deep convolution neural network based approach for classiﬁcation of diabetic retinopathy.DE
# GRUYTER: Bio-Algorithms and Med-Systems. Published Online: 2018-06-22.
# DOI:https://doi.org/10.1515/bams-2018-0011
# Projects
#
# Title Intent Classiﬁcation using a Deep Learning Bag-of-Words Model for Predicting Movie Review Sentiment
# Description A multilayer Perceptron bag-of-words model is build on a movie review corpus. The model is built for
# sentiment analysis purpose to distinguish between a positive and negative reviews. A basic sequential
# model is created using Keras, after preprocessing of the movie review corpus.
#
# Project link Github repo
#
# Title An Ensemble model for Diabetic retninopathy detection
#
# Description A model is trained and tested using ensemble learning approach. Diﬀerent Machine learning classiﬁers
# are used such as SVM, MLP, KNN, Random Forest, Decision tree, Adaboost for classiﬁcation purpose.
# Ensemble model works upon majority voting criteria. all diﬀerent classiﬁers trained with same training
# data and then tested using uniform and weighted voting Ensemble model.
#
# Project link Github repo
#
# Major Competencies
#
# E2 Digital : Deep Learning
# E2 Digital : Artiﬁcial Intelligence(AI)
# E2 Digital : Machine Learning
# E1 Digital : Data Science
#
# Specialization
# Deep Learning, a 5-course specialization by deeplearning.ai on Coursera. Specialization Certiﬁcate
# earned on September 29, 2018. Certiﬁcate link
#
# 2/3
#
# Applied Data Science with Python, a 5-course specialization by University of Michigan on Coursera.
# Specialization Certiﬁcate earned on October 4, 2018. Certiﬁcate link
# Certiﬁcation
#
# * Machine Learning by Stanford University on Coursera. Certiﬁcate link
# * Elements Of AI by University of Helsinki,Finland Certiﬁcate link
# * Natural Language Processing by National Research University Higher School of Economics on Coursera.
#
# Certiﬁcate link
#
# * Machine Learning: Regression by University of Washington on Coursera. Certiﬁcate link
# * Machine Learning: Classiﬁcation by University of Washington on Coursera. Certiﬁcate link
# * Advanced RPA Professional Certiﬁcation, License AAADVC-34652219
#
# Programming Languages
#
# Langauge Python, C++, C
# Markup LATEX, HTML,CSS
#
# VersionControl GIT
# WebFramework Flask,Django
# OS Linux,Windows
#
# Achievements and Award
#
# * University Topper in B.Tech ECE (Honours) with CGPA 9.27, Awarded with Academic Honor Certiﬁcate.
# * I have taken the i-class of diﬀerent ILP associates in a live session on the topic of Machine Learning,
#
# The participant ILP were from Hyderabad, Chennai, Trivandrum, Guwahati and Gandhinagar.
#
# * Cleared GATE 2016 with 97.45 percentile.
# * National cadet corps for ’A’ certiﬁcate.
# * Stood Second Place in Inter- IIIT Sports meet in basketball.
# * First Position in Regional level Basketball championship under K.V.S Chandigarh region-2010
#
# Competitive
# Programming
#
# Interest
# I am very much interested in solving problems. I use git for my projects and all the projects mentioned
# are on the Github as a public repo. Excluding some, they are ongoing projects and are as a private
# repository of github.
#
# Teaching I am a strong believer that the best way to learn is to teach, I love to teach
#
# Proudly made in LATEX
#
# 3/3
